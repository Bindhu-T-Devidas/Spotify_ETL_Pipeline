# %%
# !pip install spotipy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# HERE WE HAVE FOCUSED ON EXTRACTION AND TRANSFORMATION PART OF ETL. we have chosen Spotify API and we have extracted JSON RAW Data from there, then we have transformed it

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credential_manager = SpotifyClientCredentials(client_id="efaeef50068445d6a32c34c870a594a6" , client_secret= "ad81400173854f65a60dee42f44351c7")

# %%
sp = spotipy.Spotify(client_credentials_manager= client_credential_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
sp = Spotify(auth_manager=SpotifyOAuth(
    client_id="efaeef50068445d6a32c34c870a594a6",
    client_secret="ad81400173854f65a60dee42f44351c7",
    redirect_uri="http://localhost:8886/callback"
))

# %%
data = sp.playlist_tracks(playlist_URI)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-11-01T12:38:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/6b7763066dd42d94dc893f12bb135d7d5392e386?cid=efaeef50068445d6a32c34c870a594a6',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
data['items'][0] #first album info
# Out:
# {'added_at': '2024-11-01T12:38:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/6b7763066dd42d94dc893f12bb135d7d5392e386?cid=efaeef50068445d6a32c34c870a594a6',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
data['items'][1] #second album info
# Out:
# {'added_at': '2024-11-01T12:38:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
len(data['items'])  #number of songs
# Out:
# 50

# %% [markdown]
# INFO OF SINGLE ALBUM

# %%
data['items'][0]['track'] #track of first album
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/6b7763066dd42d94dc893f12bb135d7d5392e386?cid=efaeef50068445d6a32c34c870a594a6',
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
# ...

# %%
data['items'][0]['track']['album']#first album info
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
# ...

# %%
data['items'][0]['track']['album']['id'] #id of the first album
# Out:
# '2IYQwwgxgOIn7t3iF6ufFD'

# %%
data['items'][0]['track']['album']['name'] #name of the album
# Out:
# 'APT.'

# %%
data['items'][0]['track']['album']['release_date'] #release date of the album
# Out:
# '2024-10-18'

# %%
data['items'][0]['track']['album']['total_tracks'] #total number of  of the album
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls'] #url of the album
# Out:
# {'spotify': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'

# %% [markdown]
# Now we do extraction like this for all the other songs
# We get a JSON data from the source API that is stored in data and then we do the following steps to :
# 1. convert each and every info from JSON to a dictiornry having individual album details.
# 2. we then put all the dictionary to the list
#
# NOW, WE HAVE EXTRACTED AND TRANSFORMED THE DATA FROM MESSY JSON TO CLEAN LISTS

# %%
album_list= []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name= row['track']['album']['name']
    album_release_date =row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_name)
    album_element= {'album_id':album_id ,'album_name':album_name ,'album_release_date': album_release_date , 'album_total_tracks':album_total_tracks , 'album_url':album_url}
    print(album_element)
    album_list.append(album_element)
    print(album_list)
# Out:
# APT.
# {'album_id': '2IYQwwgxgOIn7t3iF6ufFD', 'album_name': 'APT.', 'album_release_date': '2024-10-18', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'}
# [{'album_id': '2IYQwwgxgOIn7t3iF6ufFD', 'album_name': 'APT.', 'album_release_date': '2024-10-18', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'}]
# Die With A Smile
# {'album_id': '10FLjwfpbxLmW8c25Xyc2N', 'album_name': 'Die With A Smile', 'album_release_date': '2024-08-16', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}
# ...

# %%
album_list
# Out:
# [{'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'album_name': 'APT.',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#  {'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'album_release_date': '2024-08-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'album_release_date': '2024-07-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '60cQzWfmdg4hyDXrpW6kOA',
#   'album_name': 'Tu Boda',
#   'album_release_date': '2024-09-26',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#   'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#   'id': '3eVa5w3URK5duf6eyVDbu9',
#   'name': 'ROSÉ',
#   'type': 'artist',
#   'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value ['artists']:
               artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
               artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
# ...

# %% [markdown]
# Doing the same for SONGS

# %%
songs_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name= row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity= row['track']['popularity']
    song_added = row['added_at']
    album_id= row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element= {'song_id':song_id, 'song_name':song_name,
                   'duration_ms':song_duration , 'url': song_url , 'popularity': song_popularity , 
                   'song_added': song_added , 'album_id':album_id, 'artist_id': artist_id
                   }
    songs_list.append(song_element)

# %%
songs_list
# Out:
# [{'song_id': '5vNRhkKd0yEAg8suGBpjeY',
#   'song_name': 'APT.',
#   'duration_ms': 169917,
#   'url': 'https://open.spotify.com/track/5vNRhkKd0yEAg8suGBpjeY',
#   'popularity': 96,
#   'song_added': '2024-11-01T12:38:25Z',
#   'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'artist_id': '3eVa5w3URK5duf6eyVDbu9'},
#  {'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'popularity': 100,
#   'song_added': '2024-11-01T12:38:25Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 97,
#   'song_added': '2024-11-01T12:38:25Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id            album_name album_release_date  \
# 0  2IYQwwgxgOIn7t3iF6ufFD                  APT.         2024-10-18
# 1  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile         2024-08-16
# 2  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT         2024-05-17
# 3  15XcLhiVMlSOipUddTNDnr                  MUSE         2024-07-19
# 4  60cQzWfmdg4hyDXrpW6kOA               Tu Boda         2024-09-26
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/2IYQwwgxgOIn7t3...
# 1                   1  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 2                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3                   7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 4                   1  https://open.spotify.com/album/60cQzWfmdg4hyDX...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset= ['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  3eVa5w3URK5duf6eyVDbu9           ROSÉ
# 1  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 2  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 3  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 4  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/6qqNVTkY8uB...

# %%
artist_df=artist_df.drop_duplicates(subset= ['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  3eVa5w3URK5duf6eyVDbu9           ROSÉ
# 1  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 2  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 4  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
# 5  1oSPZhvZMIrWW5I41kPkkY          Jimin
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 4  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 5  https://api.spotify.com/v1/artists/1oSPZhvZMIr...

# %%
song_df = pd.DataFrame.from_dict(songs_list)

# %%
song_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  5vNRhkKd0yEAg8suGBpjeY                APT.       169917
# 1  2plbrEY59IikOBgBGLjaoe    Die With A Smile       251667
# 2  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
# 3  7tI8dRuH2Yc6RuoTjxo4dU                 Who       170887
# 4  1cOboCuWYI2osTOfolMRS6             Tu Boda       225880
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5vNRhkKd0yEAg8s...          96
# 1  https://open.spotify.com/track/2plbrEY59IikOBg...         100
# 2  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          97
# 3  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          92
# 4  https://open.spotify.com/track/1cOboCuWYI2osTO...          91
#
#              song_added                album_id               artist_id
# 0  2024-11-01T12:38:25Z  2IYQwwgxgOIn7t3iF6ufFD  3eVa5w3URK5duf6eyVDbu9
# 1  2024-11-01T12:38:25Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# ...

# %% [markdown]
# DISPLAYING ALL THE DATAFRAMES WE HAVE CREATED

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   5vNRhkKd0yEAg8suGBpjeY                                               APT.
# 1   2plbrEY59IikOBgBGLjaoe                                   Die With A Smile
# 2   6dOtVTDdiauQNBQEDOtlAB                                 BIRDS OF A FEATHER
# 3   7tI8dRuH2Yc6RuoTjxo4dU                                                Who
# 4   1cOboCuWYI2osTOfolMRS6                                            Tu Boda
# 5   5G2f63n7IPVPPjfNIGih7Q                                              Taste
# 6   2HRqTpkrJO5ggZyyK6NPWz                                           Espresso
# 7   2262bWmqomIaJXwCRHr13j                                        Sailor Song
# 8   1YdtGoSYDvVQKoUqSDXX41                                               Noid
# 9   1QoyuMHNBe7lg3YW4Qtll4                   St. Chroma (feat. Daniel Caesar)
# 10  0WbMK4wrZ1wFSty9F7FCgu                                   Good Luck, Babe!
# ...

# %%
artist_df
# Out:
#                  artist_id         artist_name  \
# 0   3eVa5w3URK5duf6eyVDbu9                ROSÉ
# 1   0du5cEVh5yTK9QJze8zA0C          Bruno Mars
# 2   1HY2Jd0NmPuamShAr6KMms           Lady Gaga
# 4   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish
# 5   1oSPZhvZMIrWW5I41kPkkY               Jimin
# 6   3l9G1G9MxH6DaRhwLklaf5        Oscar Maydon
# 7   0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida
# 8   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter
# 10  1iCnM8foFssWlPRLfAbIwo          Gigi Perez
# 11  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator
# 13  20wkVLutqVOYrc0kxFs7rA       Daniel Caesar
# 14  7GlBOeep6PqTfFi59PTUUN       Chappell Roan
# 15  790FomKkXshlbRYZFtlgla             KAROL G
# 16  4AK6F7OLvEQ5QYCBNiQWHq       One Direction
# 17  5L1lO4eRHmJ7a0Q6csE5cT                LISA
# 18  1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd
# 19  699OTQXzgjhIYAHMy9RyPD       Playboi Carti
# 20  4tuJ0bMpJh08umKkEXKUI5       Gracie Abrams
# 22  22wbnEMDvgVIAGdFeek6ET        Benson Boone
# ...

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   2IYQwwgxgOIn7t3iF6ufFD                                               APT.
# 1   10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
# 2   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 3   15XcLhiVMlSOipUddTNDnr                                               MUSE
# 4   60cQzWfmdg4hyDXrpW6kOA                                            Tu Boda
# 5   3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 7   68CN2LzY8MoxO2udy2C22e                                        Sailor Song
# 8   0U28P0QVB1QRxpqp5IHOlH                                        CHROMAKOPIA
# 10  1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 11  5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 12  4gCNyS7pidfK3rKWhB3JOY                                      FOUR (Deluxe)
# ...

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            39 non-null     object
#  1   album_name          39 non-null     object
#  2   album_release_date  39 non-null     datetime64[ns]
#  3   album_total_tracks  39 non-null     int64
#  4   album_url           39 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.8+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
